# %% [markdown]
# # Assignment
#
# In this assignment, you are expected to (1) explore the Schelling Agent Based Model (ABM), (2) showcase your understanding of how the Schelling model relates to key ABM properties/aspects/concepts and (3) reflect on the Schelling ABM outcomes.
#
# This document is structured as follows:
# 1. [Schelling model description](#1)
# 2. [Explore Schelling model](#2) (through hands-on runs)
# 3. [Assignment questions](#3)
# 4. [Student input](#4) (answers to the assignment question as a student input)
#
# ---

# %% [markdown]
# ## Schelling model desciption <a id='1'></a>
#
# The Schelling model is an abstract model that explores the effect of individual relocation behaviours on macroscale segregation.
# The Schelling Agent Based Moodel (ABM) includes: a space, and agents and objects that temporally interact with each other and with the model space.
# We describe each component of the Schelling ABM hereafter.
#
# ### Space
# The space is represented as a grid of square cells. Each grid cell represents a spatial unit that one agent can occupy.
# Each spatial unit has 8 immediate surrounding neighbours defined as the "Moore neighbourhood".
#
# ### Agents
# The model includes one type of agent representing an individual or a household.
# Each agent has the following state parameters (i.e., variables that dictate the state of the agent during the simulation):
# 1. `happy?`           ; indicates whether the agent is happy or not (happy agents have a percentage of surrounding similar agents above the `similarity_threshold`)
# 2. `similar-nearby`   ; the number of neighboring spatial units that have an agent similar to the agent under analysis
# 3. `other-nearby`     ; the number of neighbouring agents that are different from the agent under analysis
# 4. `total-nearby`     ; the total numebr of neighbouring agents
#
# Agents aim to settle in a spatial unit that makes them happy by being surrounding with a high ratio of simiar agents in their Moore neighbourhood. If the agent is unhappy (due to being surrounded by a high ratio of agents different from itself), the agent moves from the current spatial unit to another one randomly. The decision tree of the agents can be summarised as follows:
# - if `similar-nearby / total-nearby > similarity_threshold` (i.e., surrrounded by many similar agents) --> happy --> remain in current spatial unit
# - if `other-nearby / total-nearby > similarity_threshold` (i.e., surrrounded by many different agents) --> unhappy --> move to another random spatial unit
#
# ### Temporality
# Each time step in the model represents an iteration where each agent checks whether they are happy or not. Following the previously stated decision tree, each agent decides whether it will move or not.
#
# ---

# %% [markdown]
# ## Explore the Schelling model <a id='2'></a>
#
# To explore the Schelling model, we provide an ABM version that runs in a Python notebook.
# The models runs by calling the `run_schelling_model()` function, which has the following input parameters:
# 1. `steps`: the number of time steps the model runs
# 2. `width`: the total width of the simulated grid space where each unit is a square cell
# 3. `height`: the total height of the simulated grid space where each unit is a square cell
# 4. `density`: the ratio between the occupied and vacant spatial grid cells
#
# It should be noted that:
# 1. The type of the agent is represented visually by colours
# (<span style="background-color: yellow">yellow</span> and <span style="background-color: blue">blue</span>)
# 2. The ratio between the two different types of agents is always 0.5 (50% of the agents are yellow and the rest are blue)
# 3. At inialisation, the exact locations of agents are randomised while maintaining the required input `density`. This implies that different spatial patterns may be observed across different runs using the same input parameters.
#
# For guidance on the required Python libraries to run the model in this Python Jupyter notebook, visit the this GitHub link: [GitHub link](https://github.com/YahyaGamal/Schelling_ABM_assignment).
# If you cannot run the model in the Jupyter notebook, you can run an online version of the model through this [NetLogo Web link](https://www.netlogoweb.org/launch#https://www.netlogoweb.org/assets/modelslib/Sample%20Models/Social%20Science/Segregation.nlogox) (note that the `similarity_threshold` is labelled as `%-similar-wanted` in the NetLogo version).
#
# When exploring the model, consider modifying the input parameters while monitoring the following outputs:
# 1. The spatial patterns at the end of the runs
# 2. The percentage of unhappy agents at initialisation and at the end of the run
# 3. The rate of change of the percentage of unhappy agents in the system
#
# This exploration process will be helpful in addressing the assignment questions stated at the end of this notebook
#
# [OPTIONAL] You can explore the full python ABM code is available in the `\schelling.py` file for a deeper understanding of how the model functions. This is not required for the assignment.

# %%
! pip install numpy==1.26.4 ipython==8.32.0 pillow==12.1.1

# %%
## Import the function from the schelling.py file
from schelling_py14 import run_schelling_model
from IPython.display import HTML

## Run the model and visualise the outcomes
run_schelling_model(
    steps=30,
    density=0.7,
    similarity_threshold=0.7
)

HTML(filename="schelling.html")
# Out:
# Running Schelling model: 30 steps on a 50×50 grid...
#   Step   1: 53.8% similar, 74.2% unhappy
#   Step  10: 70.1% similar, 45.3% unhappy
#   Step  20: 77.0% similar, 33.6% unhappy
#   Step  30: 81.8% similar, 26.8% unhappy
# Rendering complete. Writing HTML...
# Saved → d:\Glasgow\advanced topic for urban amalytics\URBAN5160_ABMs\Assignment\Python_14\schelling.html
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <title>Schelling Segregation Model</title>
# <style>
#   * { box-sizing: border-box; margin: 0; padding: 0; }
#   body {
#     font-family: 'Segoe UI', sans-serif;
#     background: #1e1e2e; color: #cdd6f4;
#     display: flex; flex-direction: column; align-items: center;
#     padding: 28px 16px;
#   }
#   h1 { font-size: 1.3rem; margin-bottom: 4px; }
#   .subtitle { font-size: 0.78rem; color: #888; margin-bottom: 18px; text-align: center; }
#
#   #display {
#     border-radius: 8px;
#     box-shadow: 0 4px 24px rgba(0,0,0,0.55);
# ...

# %% [markdown]
# ---
# ## Assignment questions <a id='3'></a>
#
# Part 1: What are ABMs, and what are their key features? Cite at least 2 examples.
#
# ---
#
# Part 2:
#
# Questions that may not need support from run results:
# 1. What are the key aims of the Schelling ABM?
#     - For instance, does it aim to predict, understand reality, explore different scenarios?
#     - Elaborate on how well you think the model achieves such aim(s)
# 2. What are the key ABM properties that the Schelling ABM showcases?
#     - Consider concepts such as emergence, complexity, interactions, behaviours... etc.
# 3. How can the insights from this ABM be useful in real life applications?
#     - For instance, can it be used to inform policies, or to enhance our understanding of segregation?
#
# Questions that can be supported by runs results:
#
# 4. How does the (spatial) outcomes change across runs with similar model inputs?
#     - In other words, does the random spatial initialisation of agents affect the macroscale outcomes?
# 5. How does modifying the `similarity_threshold` affect the outcomes? you can consider the following at different `similarity_threshold` values:
#     - whether segregation is reached
#     - the rate of reaching a stable spatial output if applicable (i.e., the number of steps)
# 6. To what extent does the initial state affects the outcomes of the model?
#     - Consider modifying the `density` to explore the outcomes?
#
# ---
#
# Part 3: Critically Evaluate the Schelling model (is it fit for purpose?)
#
# ---
#
# We estimate 1500 word assignments. Students are expected to add their writing to this Jupyter notebook and submit as an HTML.

# %% [markdown]
# ## Part 1
#
# Agent-Based Models (ABMs) are computational modelling approaches used to simulate the actions and interactions of autonomous agents within a defined system. Each agent operates according to a set of relatively simple behavioural rules, and through repeated interactions, complex patterns can emerge at the macro level. This makes ABMs particularly useful for exploring systems where global patterns are not directly programmed, but instead arise from local behaviours.
#
# ABMs are characterised by several key features. Firstly, agents are autonomous and make decisions independently based on local information rather than global knowledge. Secondly, agents interact with one another and their surrounding environment, producing dynamic system behaviour that evolves over time. Thirdly, ABMs generate emergent outcomes, where large-scale patterns arise from simple local interactions. Finally, these models evolve over time, making them particularly useful for analysing dynamic and non-linear systems where cause-and-effect relationships are not always straightforward.
#
# Examples of ABMs include the Schelling segregation model, which illustrates how individual preferences can lead to spatial segregation, and epidemiological models that simulate the spread of infectious diseases within populations. These examples highlight how ABMs can be applied to both social and natural systems.
#
# ---
#
# ## Part 2
#
# ### Question 1
#
# The primary aim of the Schelling model is not to provide precise predictions, but rather to explore and explain how individual-level preferences can lead to unexpected collective outcomes. In particular, it helps to reveal the underlying mechanisms that drive segregation, showing how individual decisions can accumulate into large-scale patterns.
#
# The model is highly effective in demonstrating that even relatively mild preferences for similar neighbours can produce strong patterns of segregation. This is important because it suggests that segregation does not necessarily require extreme bias. However, its predictive capacity is limited, as it simplifies many important real-world factors, such as economic conditions, institutional constraints, and broader social dynamics. As a result, it should be interpreted as an exploratory tool rather than a predictive one.
#
# ---
#
# ### Question 2
#
# The Schelling model demonstrates several key features of Agent-Based Models. Agents are autonomous and follow simple rules based on a similarity threshold, and their behaviour is influenced by local interactions with neighbouring agents rather than any central control.
#
# Most importantly, the model illustrates the concept of emergence. Although individual agents do not intend to create segregation, large-scale segregated patterns arise from their local decisions. This highlights how complex outcomes at the system level can emerge from relatively simple micro-level interactions. It also shows the importance of bottom-up processes in shaping social phenomena.
#
# ---
#
# ### Question 3
#
# The model is highly relevant to real-world issues such as residential segregation in urban areas. It shows how individual preferences, even when not extreme, can lead to significant separation between different social groups. This provides a useful explanation for patterns observed in many cities.
#
# This has important implications for urban planning and policy-making, as it suggests that segregation may arise even without strong individual bias. Policymakers may therefore need to consider structural interventions rather than focusing only on individual attitudes. However, real-world segregation is also shaped by additional factors, including income inequality, institutional policies, and historical processes, which are not captured in the model.
#
# ---
#
# ### Question 4
#
# When running the model multiple times with the same parameters, the specific spatial configurations differ due to the random initial distribution of agents. In my simulation, although the arrangement of clusters varied between runs, the overall pattern remained consistent, demonstrating the role of randomness in shaping local outcomes.
#
# Across runs, the model tends to evolve towards segregation, with clusters of similar agents forming over time. In this particular simulation, the percentage of similar neighbours increased steadily to approximately 85%, while the proportion of unhappy agents decreased significantly over the 30 steps. This suggests that, despite randomness at the micro level, the model produces stable and predictable macro-level outcomes. It also highlights the importance of stochastic processes in ABMs.
#
# ---
#
# ### Question 5
#
# The similarity threshold has a significant impact on the level of segregation observed in the model. In my simulation, with a threshold of 0.7, clear segregation emerges, with large clusters of similar agents forming as the system evolves.
#
# As the simulation progresses, the proportion of similar neighbours increases, while the percentage of unhappy agents decreases. This indicates that agents relocate in order to achieve neighbourhoods that satisfy their preferences. If the threshold were lower, the system would likely remain more mixed, as agents would tolerate more diversity. Conversely, a higher threshold would lead to stronger segregation and potentially faster clustering, as more agents would initially be dissatisfied. This reflects how stricter individual preferences can accelerate the formation of homogeneous clusters and influence the overall dynamics of the system.
#
# ---
#
# ### Question 6
#
# The initial density of the system influences how easily agents can move and reach a stable configuration. In this simulation, a density of 0.7 provides a balance between occupied and empty spaces, allowing agents to relocate while still interacting frequently with others.
#
# With this level of density, the model approaches a relatively stable state within 30 steps, as indicated by the gradual increase in similarity and the decrease in unhappy agents. If the density were lower, agents would have more empty spaces available, potentially allowing the system to stabilise more quickly. In contrast, a higher density would restrict movement, making it more difficult for agents to find suitable positions and slowing down the convergence process. This demonstrates the importance of spatial constraints in shaping the system’s dynamics and long-term outcomes.
#
# ---
#
# ## Part 3
#
# The Schelling model has several strengths. It is conceptually simple, yet highly effective in demonstrating how complex social patterns, such as segregation, can emerge from individual behaviour. It provides valuable insights into the mechanisms underlying social phenomena and is widely used as a teaching and exploratory tool. Its simplicity also makes it easy to modify and extend for further analysis.
#
# However, the model also has important limitations. It oversimplifies reality by including only two types of agents and a single behavioural rule. It does not account for key real-world factors such as economic inequality, institutional policies, and cultural influences. As a result, it cannot accurately predict real-world patterns of segregation. In addition, the model assumes that agents have equal ability to move, which may not reflect real social constraints.
#
# Overall, the Schelling model is best understood as a conceptual framework for exploring underlying mechanisms rather than as a tool for precise prediction. Future extensions could incorporate more realistic assumptions, such as economic factors or policy interventions, to better reflect real-world urban dynamics.
